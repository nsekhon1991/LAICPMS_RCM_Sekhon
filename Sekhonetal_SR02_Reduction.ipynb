# %% [markdown]
# This CODE reads the final output and conducts statistical analysis on the reduced dataset. NO need to run anything related to LATools in this Colab

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/BrownPD Shared Folder/LA-ICP-MS/LA-ICP-MS reduction
# Out:
# /content/drive/.shortcut-targets-by-id/1aJZLWIPb-8rJ3BoyuDiyIzxDTj9lYctJ/BrownPD Shared Folder/LA-ICP-MS/LA-ICP-MS reduction

# %%
# Import tools
from IPython.display import display
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
#pd.set_option('display.max_rows', 500)
import matplotlib.pyplot as plt

# %%
sav_fil = '/content/drive/MyDrive/BrownPD Shared Folder/LA-ICP-MS/LA-ICP-MS reduction/LA-ICP-MS annotatioinn/Final_data/Figures/'
# SEPT 2022 DATA in ug/g
xlsx_nist_sep22 = pd.ExcelFile('/content/drive/MyDrive/BrownPD Shared Folder/LA-ICP-MS/LA-ICP-MS reduction/LA-ICP-MS annotatioinn/Final_data/avg_track_NIST_sep22.xlsx')
df1_nist_sep22 = pd.read_excel(xlsx_nist_sep22, 'Sheet3')
xlsx_best_sep22 = pd.ExcelFile('/content/drive/MyDrive/BrownPD Shared Folder/LA-ICP-MS/LA-ICP-MS reduction/LA-ICP-MS annotatioinn/Final_data/avg_track_BEST_sep22.xlsx')
df2_best_sep22 = pd.read_excel(xlsx_best_sep22, 'Sheet3')
# APRIIL 2023 DATA in ug/g
xlsx_nist_apr23 = pd.ExcelFile('/content/drive/MyDrive/BrownPD Shared Folder/LA-ICP-MS/LA-ICP-MS reduction/LA-ICP-MS annotatioinn/Final_data/avg_track_NIST_apr23.xlsx')
df1_nist_apr23 = pd.read_excel(xlsx_nist_apr23, 'Sheet3')
xlsx_best_apr23 = pd.ExcelFile('/content/drive/MyDrive/BrownPD Shared Folder/LA-ICP-MS/LA-ICP-MS reduction/LA-ICP-MS annotatioinn/Final_data/avg_track_BEST_apr23.xlsx')
df2_best_apr23 = pd.read_excel(xlsx_best_apr23, 'Sheet3')
xlsx_carb_apr23 = pd.ExcelFile('/content/drive/MyDrive/BrownPD Shared Folder/LA-ICP-MS/LA-ICP-MS reduction/LA-ICP-MS annotatioinn/Final_data/avg_track_CARB_apr23.xlsx')
df3_carb_apr23 = pd.read_excel(xlsx_carb_apr23, 'Sheet3')
# APRIIL 2023 DATA in MMOL_MOL >>> USED FOR REVISED MANUCRIPT
apr_final_nist = pd.read_excel('/content/drive/MyDrive/BrownPD Shared Folder/LA-ICP-MS/LA-ICP-MS reduction/LA-ICP-MS annotatioinn/Final_data/avg_mmolmol_ap23.xlsx','nist_50MA')
apr_final_best = pd.read_excel('/content/drive/MyDrive/BrownPD Shared Folder/LA-ICP-MS/LA-ICP-MS reduction/LA-ICP-MS annotatioinn/Final_data/avg_mmolmol_ap23.xlsx','nist_macs_50MA')
apr_final_carb = pd.read_excel('/content/drive/MyDrive/BrownPD Shared Folder/LA-ICP-MS/LA-ICP-MS reduction/LA-ICP-MS annotatioinn/Final_data/avg_mmolmol_ap23.xlsx','carb_50MA')

# %%
plt.plot(
         apr_final_nist['Distance (mm)'], apr_final_nist['Sr88_Ca43_50MA'],'r',
         apr_final_best['Distance (mm)'], apr_final_best['Sr88_Ca43_50MA'],'b',
         apr_final_carb['Distance (mm)'], apr_final_carb['Sr88_Ca43_50MA'],'g'
         )
#plt.ylim(0, 50)
plt.title('Sr88_Ca43')
plt.savefig(sav_fil+'Sr88_mmol_mol.eps')

# %%
plt.plot(
         apr_final_nist['Distance (mm)'], apr_final_nist['Mg25_Ca43_50MA'],'r',
         apr_final_best['Distance (mm)'], apr_final_best['Mg25_Ca43_50MA'],'b',
         apr_final_carb['Distance (mm)'], apr_final_carb['Mg25_Ca43_50MA'],'g'
         )
#plt.ylim(0, 50)
plt.title('Mg25_Ca43')
plt.savefig(sav_fil+'Mg25_mmol_mol.eps')

# %%
plt.plot(
         apr_final_nist['Distance (mm)'], apr_final_nist['Ba137_Ca43_50MA'],'r',
         apr_final_best['Distance (mm)'], apr_final_best['Ba137_Ca43_50MA'],'b',
         apr_final_carb['Distance (mm)'], apr_final_carb['Ba137_Ca43_50MA'],'g'
         )
#plt.ylim(0, 50)
plt.title('Ba137_Ca43')
plt.savefig(sav_fil+'Ba137_mmol_mol.eps')

# %%
plt.plot(df1_nist_sep22['Distance (mm)'], df1_nist_sep22['Sr88_Ca43_50MA'],'g',
         df2_best_sep22['Distance (mm)'], df2_best_sep22['Sr88_Ca43_50MA'],'k',
         df1_nist_apr23['Distance (mm)'], df1_nist_apr23['Sr88_Ca43_50MA'],'r',
         df2_best_apr23['Distance (mm)'],df2_best_apr23['Sr88_Ca43_50MA'],'b')
#plt.ylim(0, 50)
plt.title('Sr88_Ca43')
#plt.savefig(sav_fil+'Sr88_V2.eps')
# Out:
# Text(0.5, 1.0, 'Sr88_Ca43')

# %%
plt.plot(
         df1_nist_apr23['Distance (mm)'], df1_nist_apr23['Sr88_Ca43_50MA'],'r',
         df2_best_apr23['Distance (mm)'],df2_best_apr23['Sr88_Ca43_50MA'],'b',
         df3_carb_apr23['Distance (mm)'],df3_carb_apr23['Sr88_Ca43_50MA'],'g'
         )
#plt.ylim(0, 50)
plt.title('Sr88_Ca43')
plt.savefig(sav_fil+'Sr88_V3.eps')

# %%
plt.plot(
         df1_nist_apr23['Distance (mm)'], df1_nist_apr23['Ba137_Ca43_50MA'],'r',
         df2_best_apr23['Distance (mm)'],df2_best_apr23['Ba137_Ca43_50MA'],'b',
         df3_carb_apr23['Distance (mm)'],df3_carb_apr23['Ba137_Ca43_50MA'],'g'
         )
#plt.ylim(0, 50)
plt.title('Ba137_Ca43')
plt.savefig(sav_fil+'Ba137_V3.eps')

# %%
plt.plot(
         df1_nist_apr23['Distance (mm)'], df1_nist_apr23['Mg25_Ca43_50MA'],'r',
         df2_best_apr23['Distance (mm)'],df2_best_apr23['Mg25_Ca43_50MA'],'b',
         df3_carb_apr23['Distance (mm)'],df3_carb_apr23['Mg25_Ca43_50MA'],'g'
         )
#plt.ylim(0, 50)
plt.title('Mg25_Ca43')
#plt.savefig(sav_fil+'Mg25_V3.eps')
# Out:
# Text(0.5, 1.0, 'Mg25_Ca43')

# %%
# BOX PLOT
import seaborn as sns

df = [ apr_final_nist['Mg25_Ca43_50MA'], apr_final_best['Mg25_Ca43_50MA'], apr_final_carb['Mg25_Ca43_50MA'] ]
data = df
sns.boxplot( apr_final_carb['Mg25_Ca43_50MA'] )
plt.ylim(1,4)
plt.savefig(sav_fil+'mg_box_carb23_mmol_mol.eps')
plt.show()
